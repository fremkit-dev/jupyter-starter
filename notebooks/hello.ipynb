# %% [markdown]
# # Hello from Fremkit
#
# A starter notebook for data exploration.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Hello from Fremkit")

# %%
# Quick demo: generate and plot some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sample Plot")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()
